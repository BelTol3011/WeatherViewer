# %%
import pygeohash as pgh
import requests

# um Bilder anzuzeigen
from IPython.display import Image

# %% [raw]
# https://vector.wetter.de/data/v3.json
# https://api3.wetter.de/api/v1/current-conditions?filter%5Bgeohash%5D=u30u1x
# https://api3.wetter.de/api/v1/interactive-maps/290121-u1x0et
# https://api3.wetter.de/api/v1/dayboxes?filter%5Bgeohash%5D=u30u1d
# https://api3.wetter.de/api/v1/severe-weather-warnings?filter%5Bgeohash%5D=u30u1d

# %%
geohash = "u30u1d"

pgh.decode(geohash)
# Out:
# (51.34, 12.4)

# %%
link = "https://api.meteomatics.swiss/tiles/mix/precip_5min:mm/EPSG:3857/6/34/21/2021-01-26T17:15:00Z/256.png?style=precip_europe_segmented&access_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJ2IjoxLCJ1c2VyIjoicnRsX3dldHRlcl9kZV9tYXBzIiwiZXhwIjoxNjExNjgzNDc2LCJzdWIiOiJhY2Nlc3MifQ.dW8OIvap-ryYhuAvFcTVXnpyliuGFRmyLJ05gf2AeQIJfsFCFeIwTU190Zg2wbNDHJwZec891BeeoK9jadDFRQ"

# %%
Image(url=link)
# Out:
# <img src="https://api.meteomatics.swiss/tiles/mix/precip_5min:mm/EPSG:3857/6/34/21/2021-01-26T17:15:00Z/256.png?style=precip_europe_segmented&access_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJ2IjoxLCJ1c2VyIjoicnRsX3dldHRlcl9kZV9tYXBzIiwiZXhwIjoxNjExNjgzNDc2LCJzdWIiOiJhY2Nlc3MifQ.dW8OIvap-ryYhuAvFcTVXnpyliuGFRmyLJ05gf2AeQIJfsFCFeIwTU190Zg2wbNDHJwZec891BeeoK9jadDFRQ"/>
